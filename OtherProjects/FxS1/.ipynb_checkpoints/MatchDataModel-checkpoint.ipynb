# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'Home.settings')
django.setup()
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
from basemodels.models import Tournament, Season, Team,Match
from basemodels.models import FikstureModelData
from datetime import datetime, timedelta
import pandas as pd
from django.db import IntegrityError

class SofascoreAPI:
    def __init__(self):
        pass

    def fetch_data(self):
        data = FikstureModelData.objects.all().values()
        data_list = list(data)
        df = pd.DataFrame(data_list)
        df_exploded = df.explode('data')
        expanded_data = pd.json_normalize(df_exploded['data'])
        expanded_data['tarih'] = list(df_exploded['tarih'])
        veri = expanded_data.copy()
        veri.columns = [item.replace(".", "_") for item in veri.columns]
        return veri

    def tournament_data(self):
        verim = self.fetch_data()
        if verim is None:
            raise ValueError("Veri işlenmedi. Önce 'process_data()' metodunu çalıştırın.")
        
        # Aynı uniqueTournament_id'ye sahip olanları tekrar kontrol et
        verim = verim.drop_duplicates("tournament_uniqueTournament_id")
        
        cols = [
            "tournament_uniqueTournament_id", "tournament_name", "tournament_slug", "tournament_category_name",
            "tournament_category_slug", "tournament_uniqueTournament_category_id", 
            "tournament_uniqueTournament_hasEventPlayerStatistics", "tournament_id", "tournament_isGroup", 
            "tournament_uniqueTournament_hasPerformanceGraphFeature"
        ]
        
        for col in cols:
            if col not in verim.columns:
                verim.loc[:, col] = 0

        verim = verim[cols]

        for _, row in verim.iterrows():
            tournament_id = row['tournament_uniqueTournament_id']
            
            if pd.isna(tournament_id):
                print(f"Geçersiz tournament_uniqueTournament_id: {tournament_id}, atlanıyor.")
                continue
        
            if not Tournament.objects.filter(tournament_id=tournament_id).exists():
                Tournament.objects.create(
                    tournament_id=row['tournament_uniqueTournament_id'],
                    tournament_name=row['tournament_name'],
                    tournament_slug=row['tournament_slug'],
                    tournament_category_name=row['tournament_category_name'],
                    tournament_category_slug=row['tournament_category_slug'],
                    tournament_uniqueTournament_category_id=row['tournament_uniqueTournament_category_id'],
                    tournament_model_id=row['tournament_id'],
                    tournament_isGroup=row['tournament_isGroup'] if pd.notna(row['tournament_isGroup']) else False,
                    tournament_uniqueTournament_hasPerformanceGraphFeature=row['tournament_uniqueTournament_hasPerformanceGraphFeature'] if pd.notna(row['tournament_uniqueTournament_hasPerformanceGraphFeature']) else False
                )
                print(f"Tournament ID {tournament_id} başarıyla eklendi.")
            else:
                print(f"Tournament ID {tournament_id} zaten mevcut, eklenmedi.")

    def season_data(self):
        verim = self.fetch_data()
        if verim is None:
            raise ValueError("Veri işlenmedi. Önce 'process_data()' metodunu çalıştırın.")
        
        verim = verim.drop_duplicates("season_id")
        
        season_cols = ["season_id", "season_name", "season_year","tournament_uniqueTournament_id"]

        for col in season_cols:
            if col not in verim.columns:
                verim.loc[:, col] = 0

        verim = verim[season_cols]

        for _, row in verim.iterrows():
            season_id = row['season_id']
            tournament_id = row.get('tournament_uniqueTournament_id')
    
            if pd.isna(season_id) or pd.isna(tournament_id):
                print(f"Geçersiz season_id veya tournament_id: Season ID={season_id}, Tournament ID={tournament_id}. Atlanıyor.")
                continue
    
            if not Season.objects.filter(season_id=season_id).exists():
                tournament_instance = Tournament.objects.filter(tournament_id=tournament_id).first()
                
                if tournament_instance:
                    Season.objects.create(
                        season_id=row['season_id'],
                        season_name=row['season_name'],
                        season_year=row['season_year'],
                        tournament=tournament_instance  # Doğru sütun adı burada kullanılıyor
                    )
                    print(f"Season ID {season_id} başarıyla eklendi.")
                else:
                    print(f"Tournament ID {tournament_id} bulunamadı, Season ID {season_id} eklenemedi.")
            else:
                print(f"Season ID {season_id} zaten mevcut, eklenmedi.")
    
   
    def team_data(self):

        data = self.fetch_data()
        homecols = [
                    "homeTeam_id", "homeTeam_name", "homeTeam_slug", "homeTeam_shortName",
                    "homeTeam_nameCode", "homeTeam_national", "tournament_uniqueTournament_id", "season_id"
                ]
        
        awaycols = [
                    "awayTeam_id", "awayTeam_name", "awayTeam_slug", "awayTeam_shortName",
                    "awayTeam_nameCode", "awayTeam_national", "tournament_uniqueTournament_id", "season_id"
                ]
        
        # Home takımı için veri seçimi ve kolon isimlerinin ayarlanması
        homedata = data[homecols]
        homedata.columns = ["team_id", "team_name", "team_slug", "team_shortName",
                                       "team_nameCode", "team_national", "tournament_id", "season_id"]
        
        # Away takımı için veri seçimi ve kolon isimlerinin ayarlanması
        awaydata = data[awaycols]
        awaydata.columns  = ["team_id", "team_name", "team_slug", "team_shortName",
                                       "team_nameCode", "team_national", "tournament_id", "season_id"]
        
        # Home ve Away takımları birleştirme
        teamdata = pd.concat([homedata, awaydata])
        teamdata = teamdata.drop_duplicates(subset=["team_id", "tournament_id", "season_id"])
       
        for _, row in teamdata.iterrows():
            team_id = row['team_id']
            tournament_id = row['tournament_id']
            season_id = row['season_id']
            
            # Geçersiz veya eksik id'leri atla
            if pd.isna(team_id) or pd.isna(tournament_id) or pd.isna(season_id):
                print(f"Geçersiz değer: Team ID={team_id}, Tournament ID={tournament_id}, Season ID={season_id}. Atlanıyor.")
                continue

            # İlgili tournament ve season nesnelerini getir
            tournament_instance = Tournament.objects.filter(tournament_id=tournament_id).first()
            season_instance = Season.objects.filter(season_id=season_id).first()

            try:
       
                team, created = Team.objects.get_or_create(
                    team_id=team_id,
                    defaults={
                        "team_name": row['team_name'],
                        "team_slug": row['team_slug'],
                        "team_shortName": row['team_shortName'],
                        "team_nameCode": row['team_nameCode'],
                        "team_national": row['team_national'],
                        "tournament": tournament_instance,
                        "season": season_instance,
                    }
                )
                if created:
                    print(f"Team ID {team_id} başarıyla eklendi.")
                else:
                    print(f"Team ID {team_id} zaten mevcut, ekleme yapılmadı.")
                    
            except IntegrityError:
                print(f"UNIQUE constraint hatası! Team ID {team_id} zaten veritabanında mevcut.")

    def match_data(self):
        # Fetch data from the API or existing model
        verim = self.fetch_data()
        if verim is None:
            raise ValueError("Veri işlenmedi. Lütfen önce 'process_data()' metodunu çalıştırın.")
        
     
     
        new_cols = ['id', 'startTimestamp', 'slug', 'tournament_uniqueTournament_id', 'season_id',
                    'roundInfo_round', 'status_type', 'homeTeam_id', 'awayTeam_id',
                    'homeScore_current', 'homeScore_period1', 'homeScore_period2', 'homeScore_normaltime',
                    'awayScore_current', 'awayScore_period1', 'awayScore_period2', 'awayScore_normaltime']
        
        df1 = verim[new_cols] 
        df1['date'] = pd.to_datetime(df1['startTimestamp'], unit='s') + timedelta(hours=3)
        df2 = df1.drop("startTimestamp", axis=1)
        df3 = df2.fillna(0)
        for _, row in df3.iterrows():
            match_id = row['id']
            tournament_id = row['tournament_uniqueTournament_id']
            season_id = row['season_id']
            home_team_id = row['homeTeam_id']
            away_team_id = row['awayTeam_id']
            
            # Geçersiz veya eksik id'leri atla
            if pd.isna(match_id) or pd.isna(tournament_id) or pd.isna(season_id) or pd.isna(home_team_id) or pd.isna(away_team_id):
                print(f"Geçersiz değer: Match ID={match_id}, Tournament ID={tournament_id}, Season ID={season_id}, Home Team ID={home_team_id}, Away Team ID={away_team_id}. Atlanıyor.")
                continue

            # İlgili foreign key nesnelerini getir
            tournament_instance = Tournament.objects.filter(tournament_id=tournament_id).first()
            season_instance = Season.objects.filter(season_id=season_id).first()
            home_team_instance = Team.objects.filter(team_id=home_team_id).first()
            away_team_instance = Team.objects.filter(team_id=away_team_id).first()
            try:
                if tournament_instance and season_instance and home_team_instance and away_team_instance:
                    # Match'in veritabanında olup olmadığını kontrol et, yoksa oluştur
                    match, created = Match.objects.get_or_create(
                        id=match_id,
                        defaults={
                            'startTimestamp': row['date'],  # DateTimeField olarak datetime verisi
                            'slug': row['slug'],
                            'tournament': tournament_instance,
                            'season': season_instance,
                            'homeTeam': home_team_instance,
                            'awayTeam': away_team_instance,
                            'roundInfo_round': row['roundInfo_round'],
                            'homeScore_current': row['homeScore_current'],
                            'homeScore_period1': row['homeScore_period1'],
                            'homeScore_period2': row['homeScore_period2'],
                            'homeScore_normaltime': row['homeScore_normaltime'],
                            'awayScore_current': row['awayScore_current'],
                            'awayScore_period1': row['awayScore_period1'],
                            'awayScore_period2': row['awayScore_period2'],
                            'awayScore_normaltime': row['awayScore_normaltime'],
                            'status_type': row['status_type']
                        }
                    )
                    if created:
                        print(f"Match ID {match_id} başarıyla eklendi.")
                    else:
                        print(f"Match ID {match_id} zaten mevcut, eklenmedi.")
                else:
                    print(f"Tournament ID {tournament_id}, Season ID {season_id}, Home Team ID {home_team_id}, Away Team ID {away_team_id} bulunamadı.")
            except IntegrityError:
                print(f"UNIQUE constraint hatası! Match ID {match_id} zaten veritabanında mevcut.")
            except Exception as e:
                print(f"Match ID {match_id} eklenirken bir hata oluştu: {e}")



# SofascoreAPI sınıfını kullanarak team_data'yı veritabanına kaydetmek için:
api = SofascoreAPI()
teamdata = api.fetch_data()  # Veriyi getirin (API'den ya da dosyadan)
api.tournament_data()
api.season_data()
api.team_data()
api.match_data()
print("İşlemler bitti")
# Out:
# Tournament ID 17 zaten mevcut, eklenmedi.
# Tournament ID 8 zaten mevcut, eklenmedi.
# Tournament ID 23 zaten mevcut, eklenmedi.
# Tournament ID 35 zaten mevcut, eklenmedi.
# Tournament ID 34 zaten mevcut, eklenmedi.
# Tournament ID 37 zaten mevcut, eklenmedi.
# Tournament ID 325 zaten mevcut, eklenmedi.
# Tournament ID 52 zaten mevcut, eklenmedi.
# Tournament ID 38 zaten mevcut, eklenmedi.
# Tournament ID 185 zaten mevcut, eklenmedi.
# Tournament ID 2132 zaten mevcut, eklenmedi.
# Tournament ID 155 zaten mevcut, eklenmedi.
# Tournament ID 11621 zaten mevcut, eklenmedi.
# Tournament ID 170 zaten mevcut, eklenmedi.
# Tournament ID 210 zaten mevcut, eklenmedi.
# Tournament ID 18 zaten mevcut, eklenmedi.
# Tournament ID 54 zaten mevcut, eklenmedi.
# Tournament ID 53 zaten mevcut, eklenmedi.
# Tournament ID 182 zaten mevcut, eklenmedi.
# Tournament ID 390 zaten mevcut, eklenmedi.
# Tournament ID 131 zaten mevcut, eklenmedi.
# Tournament ID 98 zaten mevcut, eklenmedi.
# Tournament ID 45 zaten mevcut, eklenmedi.
# Tournament ID 266 zaten mevcut, eklenmedi.
# Tournament ID 11653 zaten mevcut, eklenmedi.
# Tournament ID 11536 zaten mevcut, eklenmedi.
# Tournament ID 172 zaten mevcut, eklenmedi.
# Tournament ID 202 zaten mevcut, eklenmedi.
# Tournament ID 39 zaten mevcut, eklenmedi.
# Tournament ID 11541 zaten mevcut, eklenmedi.
# Tournament ID 240 zaten mevcut, eklenmedi.
# Tournament ID 1900 zaten mevcut, eklenmedi.
# Tournament ID 20 zaten mevcut, eklenmedi.
# Tournament ID 955 zaten mevcut, eklenmedi.
# Tournament ID 152 zaten mevcut, eklenmedi.
# Tournament ID 40 zaten mevcut, eklenmedi.
# Tournament ID 215 zaten mevcut, eklenmedi.
# Tournament ID 13362 zaten mevcut, eklenmedi.
# Tournament ID 203 zaten mevcut, eklenmedi.
# Tournament ID 1690 zaten mevcut, eklenmedi.
# Tournament ID 1032 zaten mevcut, eklenmedi.
# Tournament ID 1044 zaten mevcut, eklenmedi.
# Tournament ID 9 zaten mevcut, eklenmedi.
# Tournament ID 1139 zaten mevcut, eklenmedi.
# Tournament ID 10640 zaten mevcut, eklenmedi.
# Tournament ID 232 zaten mevcut, eklenmedi.
# Tournament ID 1127 zaten mevcut, eklenmedi.
# Tournament ID 187 zaten mevcut, eklenmedi.
# Tournament ID 211 zaten mevcut, eklenmedi.
# Tournament ID 703 zaten mevcut, eklenmedi.
# Tournament ID 463 zaten mevcut, eklenmedi.
# Tournament ID 709 zaten mevcut, eklenmedi.
# Tournament ID 846 zaten mevcut, eklenmedi.
# Tournament ID 169 zaten mevcut, eklenmedi.
# Tournament ID 16736 zaten mevcut, eklenmedi.
# Tournament ID 222 zaten mevcut, eklenmedi.
# Tournament ID 373 zaten mevcut, eklenmedi.
# Tournament ID 247 zaten mevcut, eklenmedi.
# Tournament ID 1240 zaten mevcut, eklenmedi.
# Tournament ID 11535 zaten mevcut, eklenmedi.
# Tournament ID 171 zaten mevcut, eklenmedi.
# Tournament ID 205 zaten mevcut, eklenmedi.
# Tournament ID 47 zaten mevcut, eklenmedi.
# Tournament ID 65 zaten mevcut, eklenmedi.
# Tournament ID 14688 zaten mevcut, eklenmedi.
# Tournament ID 704 zaten mevcut, eklenmedi.
# Tournament ID 491 zaten mevcut, eklenmedi.
# Tournament ID 42 zaten mevcut, eklenmedi.
# Tournament ID 1083 zaten mevcut, eklenmedi.
# Tournament ID 1079 zaten mevcut, eklenmedi.
# Tournament ID 1191 zaten mevcut, eklenmedi.
# Tournament ID 186 zaten mevcut, eklenmedi.
# Tournament ID 11619 zaten mevcut, eklenmedi.
# Tournament ID 188 zaten mevcut, eklenmedi.
# Tournament ID 1015 zaten mevcut, eklenmedi.
# Tournament ID 915 zaten mevcut, eklenmedi.
# Tournament ID 11445 zaten mevcut, eklenmedi.
# Tournament ID 11447 zaten mevcut, eklenmedi.
# Tournament ID 11446 zaten mevcut, eklenmedi.
# Tournament ID 2292 zaten mevcut, eklenmedi.
# Tournament ID 682 zaten mevcut, eklenmedi.
# Tournament ID 197 zaten mevcut, eklenmedi.
# Tournament ID 198 zaten mevcut, eklenmedi.
# Tournament ID 1000 zaten mevcut, eklenmedi.
# Tournament ID 629 zaten mevcut, eklenmedi.
# Tournament ID 11611 zaten mevcut, eklenmedi.
# Tournament ID 685 zaten mevcut, eklenmedi.
# Tournament ID 937 zaten mevcut, eklenmedi.
# Tournament ID 199 zaten mevcut, eklenmedi.
# Tournament ID 22 zaten mevcut, eklenmedi.
# Tournament ID 201 zaten mevcut, eklenmedi.
# Tournament ID 229 zaten mevcut, eklenmedi.
# Tournament ID 562 zaten mevcut, eklenmedi.
# Tournament ID 204 zaten mevcut, eklenmedi.
# Tournament ID 212 zaten mevcut, eklenmedi.
# Tournament ID 46 zaten mevcut, eklenmedi.
# Tournament ID 67 zaten mevcut, eklenmedi.
# Tournament ID 68 zaten mevcut, eklenmedi.
# Tournament ID 214 zaten mevcut, eklenmedi.
# Tournament ID 984 zaten mevcut, eklenmedi.
# Tournament ID 218 zaten mevcut, eklenmedi.
# Tournament ID 278 zaten mevcut, eklenmedi.
# Tournament ID 367 zaten mevcut, eklenmedi.
# Tournament ID 827 zaten mevcut, eklenmedi.
# Tournament ID 7 zaten mevcut, eklenmedi.
# Tournament ID 384 zaten mevcut, eklenmedi.
# Tournament ID 242 zaten mevcut, eklenmedi.
# Tournament ID 24 zaten mevcut, eklenmedi.
# Tournament ID 25 zaten mevcut, eklenmedi.
# Tournament ID 196 zaten mevcut, eklenmedi.
# Tournament ID 406 zaten mevcut, eklenmedi.
# Tournament ID 358 zaten mevcut, eklenmedi.
# Tournament ID 841 zaten mevcut, eklenmedi.
# Tournament ID 668 zaten mevcut, eklenmedi.
# Tournament ID 166 zaten mevcut, eklenmedi.
# Tournament ID 1238 zaten mevcut, eklenmedi.
# Tournament ID 173 zaten mevcut, eklenmedi.
# Tournament ID 178 zaten mevcut, eklenmedi.
# Tournament ID 55 zaten mevcut, eklenmedi.
# Tournament ID 1085 zaten mevcut, eklenmedi.
# Tournament ID 200 zaten mevcut, eklenmedi.
# Tournament ID 331 zaten mevcut, eklenmedi.
# Tournament ID 238 zaten mevcut, eklenmedi.
# Tournament ID 36 zaten mevcut, eklenmedi.
# Tournament ID 19 zaten mevcut, eklenmedi.
# Tournament ID 44 zaten mevcut, eklenmedi.
# Tournament ID 136 zaten mevcut, eklenmedi.
# Tournament ID 808 zaten mevcut, eklenmedi.
# Tournament ID 192 zaten mevcut, eklenmedi.
# Tournament ID 13470 zaten mevcut, eklenmedi.
# Tournament ID 1894 zaten mevcut, eklenmedi.
# Tournament ID 13363 zaten mevcut, eklenmedi.
# Tournament ID 410 zaten mevcut, eklenmedi.
# Tournament ID 777 zaten mevcut, eklenmedi.
# Tournament ID 971 zaten mevcut, eklenmedi.
# Tournament ID 135 zaten mevcut, eklenmedi.
# Tournament ID 782 zaten mevcut, eklenmedi.
# Tournament ID 41 zaten mevcut, eklenmedi.
# Tournament ID 183 zaten mevcut, eklenmedi.
# Tournament ID 493 zaten mevcut, eklenmedi.
# Tournament ID 402 zaten mevcut, eklenmedi.
# Tournament ID 1654 zaten mevcut, eklenmedi.
# Tournament ID 239 zaten mevcut, eklenmedi.
# Tournament ID 17101 zaten mevcut, eklenmedi.
# Tournament ID 206 zaten mevcut, eklenmedi.
# Tournament ID 207 zaten mevcut, eklenmedi.
# Tournament ID 209 zaten mevcut, eklenmedi.
# Tournament ID 332 zaten mevcut, eklenmedi.
# Tournament ID 634 zaten mevcut, eklenmedi.
# Tournament ID 231 zaten mevcut, eklenmedi.
# Tournament ID 626 zaten mevcut, eklenmedi.
# Tournament ID 254 zaten mevcut, eklenmedi.
# Season ID 61627 zaten mevcut, eklenmedi.
# Season ID 61643 zaten mevcut, eklenmedi.
# Season ID 63515 zaten mevcut, eklenmedi.
# Season ID 63516 zaten mevcut, eklenmedi.
# Season ID 61736 zaten mevcut, eklenmedi.
# Season ID 61666 zaten mevcut, eklenmedi.
# Season ID 58766 zaten mevcut, eklenmedi.
# Season ID 63814 zaten mevcut, eklenmedi.
# Season ID 61459 zaten mevcut, eklenmedi.
# Season ID 64052 zaten mevcut, eklenmedi.
# Season ID 66456 zaten mevcut, eklenmedi.
# Season ID 57478 zaten mevcut, eklenmedi.
# Season ID 61419 zaten mevcut, eklenmedi.
# Season ID 61243 zaten mevcut, eklenmedi.
# Season ID 61448 zaten mevcut, eklenmedi.
# Season ID 61961 zaten mevcut, eklenmedi.
# Season ID 62048 zaten mevcut, eklenmedi.
# Season ID 63812 zaten mevcut, eklenmedi.
# Season ID 61737 zaten mevcut, eklenmedi.
# Season ID 59015 zaten mevcut, eklenmedi.
# Season ID 61667 zaten mevcut, eklenmedi.
# Season ID 64425 zaten mevcut, eklenmedi.
# Season ID 62629 zaten mevcut, eklenmedi.
# Season ID 61932 zaten mevcut, eklenmedi.
# Season ID 57883 zaten mevcut, eklenmedi.
# Season ID 63819 zaten mevcut, eklenmedi.
# Season ID 61716 zaten mevcut, eklenmedi.
# Season ID 61236 zaten mevcut, eklenmedi.
# Season ID 61326 zaten mevcut, eklenmedi.
# Season ID 63769 zaten mevcut, eklenmedi.
# Season ID 58043 zaten mevcut, eklenmedi.
# Season ID 65961 zaten mevcut, eklenmedi.
# Season ID 57322 zaten mevcut, eklenmedi.
# Season ID 63998 zaten mevcut, eklenmedi.
# Season ID 62837 zaten mevcut, eklenmedi.
# Season ID 57284 zaten mevcut, eklenmedi.
# Season ID 61658 zaten mevcut, eklenmedi.
# Season ID 57318 zaten mevcut, eklenmedi.
# Season ID 61712 zaten mevcut, eklenmedi.
# Season ID 58145 zaten mevcut, eklenmedi.
# Season ID 63500 zaten mevcut, eklenmedi.
# Season ID 64370 zaten mevcut, eklenmedi.
# Season ID 61412 zaten mevcut, eklenmedi.
# Season ID 64322 zaten mevcut, eklenmedi.
# Season ID 63768 zaten mevcut, eklenmedi.
# Season ID 64294 zaten mevcut, eklenmedi.
# Season ID 65687 zaten mevcut, eklenmedi.
# Season ID 61714 zaten mevcut, eklenmedi.
# Season ID 61728 zaten mevcut, eklenmedi.
# Season ID 57782 zaten mevcut, eklenmedi.
# Season ID 62485 zaten mevcut, eklenmedi.
# Season ID 64075 zaten mevcut, eklenmedi.
# Season ID 65070 zaten mevcut, eklenmedi.
# Season ID 58774 zaten mevcut, eklenmedi.
# Season ID 58156 zaten mevcut, eklenmedi.
# Season ID 63463 zaten mevcut, eklenmedi.
# Season ID 58134 zaten mevcut, eklenmedi.
# Season ID 61477 zaten mevcut, eklenmedi.
# Season ID 58194 zaten mevcut, eklenmedi.
# Season ID 61711 zaten mevcut, eklenmedi.
# Season ID 63498 zaten mevcut, eklenmedi.
# Season ID 61725 zaten mevcut, eklenmedi.
# Season ID 61669 zaten mevcut, eklenmedi.
# Season ID 61929 zaten mevcut, eklenmedi.
# Season ID 67785 zaten mevcut, eklenmedi.
# Season ID 57889 zaten mevcut, eklenmedi.
# Season ID 63786 zaten mevcut, eklenmedi.
# Season ID 63874 zaten mevcut, eklenmedi.
# Season ID 63556 zaten mevcut, eklenmedi.
# Season ID 63815 zaten mevcut, eklenmedi.
# Season ID 64783 zaten mevcut, eklenmedi.
# Season ID 66662 zaten mevcut, eklenmedi.
# Season ID 61855 zaten mevcut, eklenmedi.
# Season ID 57370 zaten mevcut, eklenmedi.
# Season ID 65049 zaten mevcut, eklenmedi.
# Season ID 65237 zaten mevcut, eklenmedi.
# Season ID 63975 zaten mevcut, eklenmedi.
# Season ID 63976 zaten mevcut, eklenmedi.
# Season ID 63973 zaten mevcut, eklenmedi.
# Season ID 64432 zaten mevcut, eklenmedi.
# Season ID 58620 zaten mevcut, eklenmedi.
# Season ID 58563 zaten mevcut, eklenmedi.
# Season ID 58463 zaten mevcut, eklenmedi.
# Season ID 59816 zaten mevcut, eklenmedi.
# Season ID 65067 zaten mevcut, eklenmedi.
# Season ID 63978 zaten mevcut, eklenmedi.
# Season ID 63546 zaten mevcut, eklenmedi.
# Season ID 65433 zaten mevcut, eklenmedi.
# Season ID 64685 zaten mevcut, eklenmedi.
# Season ID 57356 zaten mevcut, eklenmedi.
# Season ID 57359 zaten mevcut, eklenmedi.
# Season ID 61452 zaten mevcut, eklenmedi.
# Season ID 64111 zaten mevcut, eklenmedi.
# Season ID 63400 zaten mevcut, eklenmedi.
# Season ID 62660 zaten mevcut, eklenmedi.
# Season ID 57444 zaten mevcut, eklenmedi.
# Season ID 57893 zaten mevcut, eklenmedi.
# Season ID 57892 zaten mevcut, eklenmedi.
# Season ID 57379 zaten mevcut, eklenmedi.
# Season ID 65503 zaten mevcut, eklenmedi.
# Season ID 62656 zaten mevcut, eklenmedi.
# Season ID 58264 zaten mevcut, eklenmedi.
# Season ID 61686 zaten mevcut, eklenmedi.
# Season ID 61934 zaten mevcut, eklenmedi.
# Season ID 61644 zaten mevcut, eklenmedi.
# Season ID 57296 zaten mevcut, eklenmedi.
# Season ID 57317 zaten mevcut, eklenmedi.
# Season ID 61959 zaten mevcut, eklenmedi.
# Season ID 61960 zaten mevcut, eklenmedi.
# Season ID 57353 zaten mevcut, eklenmedi.
# Season ID 57741 zaten mevcut, eklenmedi.
# Season ID 65113 zaten mevcut, eklenmedi.
# Season ID 64102 zaten mevcut, eklenmedi.
# Season ID 62486 zaten mevcut, eklenmedi.
# Season ID 61661 zaten mevcut, eklenmedi.
# Season ID 57388 zaten mevcut, eklenmedi.
# Season ID 63807 zaten mevcut, eklenmedi.
# Season ID 57905 zaten mevcut, eklenmedi.
# Season ID 58125 zaten mevcut, eklenmedi.
# Season ID 61829 zaten mevcut, eklenmedi.
# Season ID 62405 zaten mevcut, eklenmedi.
# Season ID 63699 zaten mevcut, eklenmedi.
# Season ID 63670 zaten mevcut, eklenmedi.
# Season ID 62408 zaten mevcut, eklenmedi.
# Season ID 67958 zaten mevcut, eklenmedi.
# Season ID 63514 zaten mevcut, eklenmedi.
# Season ID 64864 zaten mevcut, eklenmedi.
# Season ID 68147 zaten mevcut, eklenmedi.
# Season ID 57285 zaten mevcut, eklenmedi.
# Season ID 58120 zaten mevcut, eklenmedi.
# Season ID 66775 zaten mevcut, eklenmedi.
# Season ID 57319 zaten mevcut, eklenmedi.
# Season ID 57878 zaten mevcut, eklenmedi.
# Season ID 57993 zaten mevcut, eklenmedi.
# Season ID 64629 zaten mevcut, eklenmedi.
# Season ID 62657 zaten mevcut, eklenmedi.
# Season ID 58844 zaten mevcut, eklenmedi.
# Season ID 57896 zaten mevcut, eklenmedi.
# Season ID 64124 zaten mevcut, eklenmedi.
# Season ID 63813 zaten mevcut, eklenmedi.
# Season ID 57365 zaten mevcut, eklenmedi.
# Season ID 66750 zaten mevcut, eklenmedi.
# Season ID 63676 zaten mevcut, eklenmedi.
# Season ID 63870 zaten mevcut, eklenmedi.
# Season ID 62411 zaten mevcut, eklenmedi.
# Season ID 62416 zaten mevcut, eklenmedi.
# Season ID 62487 zaten mevcut, eklenmedi.
# Season ID 61176 zaten mevcut, eklenmedi.
# Season ID 59708 zaten mevcut, eklenmedi.
# Season ID 57694 zaten mevcut, eklenmedi.
# Season ID 65000 zaten mevcut, eklenmedi.
# Season ID 61811 zaten mevcut, eklenmedi.
# Team ID 3 zaten mevcut, ekleme yapılmadı.
# Team ID 44 zaten mevcut, ekleme yapılmadı.
# Team ID 14 zaten mevcut, ekleme yapılmadı.
# Team ID 2826 zaten mevcut, ekleme yapılmadı.
# Team ID 2836 zaten mevcut, ekleme yapılmadı.
# Team ID 2819 zaten mevcut, ekleme yapılmadı.
# Team ID 2817 zaten mevcut, ekleme yapılmadı.
# Team ID 2828 zaten mevcut, ekleme yapılmadı.
# Team ID 2689 zaten mevcut, ekleme yapılmadı.
# Team ID 2688 zaten mevcut, ekleme yapılmadı.
# Team ID 2719 zaten mevcut, ekleme yapılmadı.
# Team ID 2702 zaten mevcut, ekleme yapılmadı.
# Team ID 2701 zaten mevcut, ekleme yapılmadı.
# Team ID 2573 zaten mevcut, ekleme yapılmadı.
# Team ID 2524 zaten mevcut, ekleme yapılmadı.
# Team ID 1662 zaten mevcut, ekleme yapılmadı.
# Team ID 1646 zaten mevcut, ekleme yapılmadı.
# Team ID 1647 zaten mevcut, ekleme yapılmadı.
# Team ID 1681 zaten mevcut, ekleme yapılmadı.
# Team ID 1642 zaten mevcut, ekleme yapılmadı.
# Team ID 2951 zaten mevcut, ekleme yapılmadı.
# Team ID 2977 zaten mevcut, ekleme yapılmadı.
# Team ID 2971 zaten mevcut, ekleme yapılmadı.
# Team ID 1980 zaten mevcut, ekleme yapılmadı.
# Team ID 3050 zaten mevcut, ekleme yapılmadı.
# Team ID 6362 zaten mevcut, ekleme yapılmadı.
# Team ID 3053 zaten mevcut, ekleme yapılmadı.
# Team ID 202390 zaten mevcut, ekleme yapılmadı.
# Team ID 2918 zaten mevcut, ekleme yapılmadı.
# Team ID 2901 zaten mevcut, ekleme yapılmadı.
# Team ID 5044 zaten mevcut, ekleme yapılmadı.
# Team ID 3245 zaten mevcut, ekleme yapılmadı.
# Team ID 3241 zaten mevcut, ekleme yapılmadı.
# Team ID 3252 zaten mevcut, ekleme yapılmadı.
# Team ID 3250 zaten mevcut, ekleme yapılmadı.
# Team ID 174568 zaten mevcut, ekleme yapılmadı.
# Team ID 90120 zaten mevcut, ekleme yapılmadı.
# Team ID 90122 zaten mevcut, ekleme yapılmadı.
# Team ID 120874 zaten mevcut, ekleme yapılmadı.
# Team ID 90138 zaten mevcut, ekleme yapılmadı.
# Team ID 42729 zaten mevcut, ekleme yapılmadı.
# Team ID 3216 zaten mevcut, ekleme yapılmadı.
# Team ID 3206 zaten mevcut, ekleme yapılmadı.
# Team ID 3217 zaten mevcut, ekleme yapılmadı.
# Team ID 6074 zaten mevcut, ekleme yapılmadı.
# Team ID 3201 zaten mevcut, ekleme yapılmadı.
# Team ID 1933 zaten mevcut, ekleme yapılmadı.
# Team ID 2042 zaten mevcut, ekleme yapılmadı.
# Team ID 231380 zaten mevcut, ekleme yapılmadı.
# Team ID 7771 zaten mevcut, ekleme yapılmadı.
# Team ID 25736 zaten mevcut, ekleme yapılmadı.
# Team ID 96 zaten mevcut, ekleme yapılmadı.
# Team ID 4488 zaten mevcut, ekleme yapılmadı.
# Team ID 2843 zaten mevcut, ekleme yapılmadı.
# Team ID 2846 zaten mevcut, ekleme yapılmadı.
# Team ID 2815 zaten mevcut, ekleme yapılmadı.
# Team ID 2848 zaten mevcut, ekleme yapılmadı.
# Team ID 2745 zaten mevcut, ekleme yapılmadı.
# Team ID 5324 zaten mevcut, ekleme yapılmadı.
# Team ID 24516 zaten mevcut, ekleme yapılmadı.
# Team ID 2742 zaten mevcut, ekleme yapılmadı.
# Team ID 1652 zaten mevcut, ekleme yapılmadı.
# Team ID 39634 zaten mevcut, ekleme yapılmadı.
# Team ID 1969 zaten mevcut, ekleme yapılmadı.
# Team ID 1959 zaten mevcut, ekleme yapılmadı.
# Team ID 21845 zaten mevcut, ekleme yapılmadı.
# Team ID 2974 zaten mevcut, ekleme yapılmadı.
# Team ID 46160 zaten mevcut, ekleme yapılmadı.
# Team ID 46168 zaten mevcut, ekleme yapılmadı.
# Team ID 2970 zaten mevcut, ekleme yapılmadı.
# Team ID 6414 zaten mevcut, ekleme yapılmadı.
# Team ID 388264 zaten mevcut, ekleme yapılmadı.
# Team ID 3080 zaten mevcut, ekleme yapılmadı.
# Team ID 262480 zaten mevcut, ekleme yapılmadı.
# Team ID 43254 zaten mevcut, ekleme yapılmadı.
# Team ID 5405 zaten mevcut, ekleme yapılmadı.
# Team ID 2055 zaten mevcut, ekleme yapılmadı.
# Team ID 86406 zaten mevcut, ekleme yapılmadı.
# Team ID 5333 zaten mevcut, ekleme yapılmadı.
# Team ID 39525 zaten mevcut, ekleme yapılmadı.
# Team ID 3157 zaten mevcut, ekleme yapılmadı.
# Team ID 3162 zaten mevcut, ekleme yapılmadı.
# Team ID 3165 zaten mevcut, ekleme yapılmadı.
# Team ID 89506 zaten mevcut, ekleme yapılmadı.
# Team ID 33596 zaten mevcut, ekleme yapılmadı.
# Team ID 48242 zaten mevcut, ekleme yapılmadı.
# Team ID 6102 zaten mevcut, ekleme yapılmadı.
# Team ID 6103 zaten mevcut, ekleme yapılmadı.
# Team ID 6106 zaten mevcut, ekleme yapılmadı.
# Team ID 6975 zaten mevcut, ekleme yapılmadı.
# Team ID 6114 zaten mevcut, ekleme yapılmadı.
# Team ID 89370 zaten mevcut, ekleme yapılmadı.
# Team ID 6117 zaten mevcut, ekleme yapılmadı.
# Team ID 6118 zaten mevcut, ekleme yapılmadı.
# Team ID 61504 zaten mevcut, ekleme yapılmadı.
# Team ID 48244 zaten mevcut, ekleme yapılmadı.
# Team ID 6105 zaten mevcut, ekleme yapılmadı.
# Team ID 4871 zaten mevcut, ekleme yapılmadı.
# Team ID 23951 zaten mevcut, ekleme yapılmadı.
# Team ID 2205 zaten mevcut, ekleme yapılmadı.
# Team ID 3110 zaten mevcut, ekleme yapılmadı.
# Team ID 35268 zaten mevcut, ekleme yapılmadı.
# Team ID 7295 zaten mevcut, ekleme yapılmadı.
# Team ID 1290 zaten mevcut, ekleme yapılmadı.
# Team ID 1756 zaten mevcut, ekleme yapılmadı.
# Team ID 1292 zaten mevcut, ekleme yapılmadı.
# Team ID 1295 zaten mevcut, ekleme yapılmadı.
# Team ID 1291 zaten mevcut, ekleme yapılmadı.
# Team ID 36439 zaten mevcut, ekleme yapılmadı.
# Team ID 5996 zaten mevcut, ekleme yapılmadı.
# Team ID 5992 zaten mevcut, ekleme yapılmadı.
# Team ID 5998 zaten mevcut, ekleme yapılmadı.
# Team ID 5249 zaten mevcut, ekleme yapılmadı.
# Team ID 213638 zaten mevcut, ekleme yapılmadı.
# Team ID 5250 zaten mevcut, ekleme yapılmadı.
# Team ID 118660 zaten mevcut, ekleme yapılmadı.
# Team ID 267915 zaten mevcut, ekleme yapılmadı.
# Team ID 1161 zaten mevcut, ekleme yapılmadı.
# Team ID 666 zaten mevcut, ekleme yapılmadı.
# Team ID 786 zaten mevcut, ekleme yapılmadı.
# Team ID 957 zaten mevcut, ekleme yapılmadı.
# Team ID 1164 zaten mevcut, ekleme yapılmadı.
# Team ID 687 zaten mevcut, ekleme yapılmadı.
# Team ID 56023 zaten mevcut, ekleme yapılmadı.
# Team ID 336456 zaten mevcut, ekleme yapılmadı.
# Team ID 34318 zaten mevcut, ekleme yapılmadı.
# Team ID 116223 zaten mevcut, ekleme yapılmadı.
# Team ID 3292 zaten mevcut, ekleme yapılmadı.
# Team ID 44319 zaten mevcut, ekleme yapılmadı.
# Team ID 295403 zaten mevcut, ekleme yapılmadı.
# Team ID 1891 zaten mevcut, ekleme yapılmadı.
# Team ID 1786 zaten mevcut, ekleme yapılmadı.
# Team ID 1758 zaten mevcut, ekleme yapılmadı.
# Team ID 1769 zaten mevcut, ekleme yapılmadı.
# Team ID 1761 zaten mevcut, ekleme yapılmadı.
# Team ID 2501 zaten mevcut, ekleme yapılmadı.
# Team ID 2446 zaten mevcut, ekleme yapılmadı.
# Team ID 2460 zaten mevcut, ekleme yapılmadı.
# Team ID 405294 zaten mevcut, ekleme yapılmadı.
# Team ID 24118 zaten mevcut, ekleme yapılmadı.
# Team ID 2333 zaten mevcut, ekleme yapılmadı.
# Team ID 34718 zaten mevcut, ekleme yapılmadı.
# Team ID 151012 zaten mevcut, ekleme yapılmadı.
# Team ID 408169 zaten mevcut, ekleme yapılmadı.
# Team ID 255498 zaten mevcut, ekleme yapılmadı.
# Team ID 254730 zaten mevcut, ekleme yapılmadı.
# Team ID 66774 zaten mevcut, ekleme yapılmadı.
# Team ID 299289 zaten mevcut, ekleme yapılmadı.
# Team ID 297802 zaten mevcut, ekleme yapılmadı.
# Team ID 66768 zaten mevcut, ekleme yapılmadı.
# Team ID 35076 zaten mevcut, ekleme yapılmadı.
# Team ID 371484 zaten mevcut, ekleme yapılmadı.
# Team ID 264964 zaten mevcut, ekleme yapılmadı.
# Team ID 301414 zaten mevcut, ekleme yapılmadı.
# Team ID 269819 zaten mevcut, ekleme yapılmadı.
# Team ID 5551 zaten mevcut, ekleme yapılmadı.
# Team ID 5550 zaten mevcut, ekleme yapılmadı.
# Team ID 36623 zaten mevcut, ekleme yapılmadı.
# Team ID 38322 zaten mevcut, ekleme yapılmadı.
# Team ID 253896 zaten mevcut, ekleme yapılmadı.
# Team ID 1922 zaten mevcut, ekleme yapılmadı.
# Team ID 1925 zaten mevcut, ekleme yapılmadı.
# Team ID 189813 zaten mevcut, ekleme yapılmadı.
# Team ID 2402 zaten mevcut, ekleme yapılmadı.
# Team ID 222120 zaten mevcut, ekleme yapılmadı.
# Team ID 213361 zaten mevcut, ekleme yapılmadı.
# Team ID 5292 zaten mevcut, ekleme yapılmadı.
# Team ID 213042 zaten mevcut, ekleme yapılmadı.
# Team ID 34976 zaten mevcut, ekleme yapılmadı.
# Team ID 43741 zaten mevcut, ekleme yapılmadı.
# Team ID 112499 zaten mevcut, ekleme yapılmadı.
# Team ID 93513 zaten mevcut, ekleme yapılmadı.
# Team ID 36834 zaten mevcut, ekleme yapılmadı.
# Team ID 107201 zaten mevcut, ekleme yapılmadı.
# Team ID 48912 zaten mevcut, ekleme yapılmadı.
# Team ID 41537 zaten mevcut, ekleme yapılmadı.
# Team ID 34218 zaten mevcut, ekleme yapılmadı.
# Team ID 3371 zaten mevcut, ekleme yapılmadı.
# Team ID 37082 zaten mevcut, ekleme yapılmadı.
# Team ID 39733 zaten mevcut, ekleme yapılmadı.
# Team ID 61532 zaten mevcut, ekleme yapılmadı.
# Team ID 40660 zaten mevcut, ekleme yapılmadı.
# Team ID 173406 zaten mevcut, ekleme yapılmadı.
# Team ID 44497 zaten mevcut, ekleme yapılmadı.
# Team ID 45474 zaten mevcut, ekleme yapılmadı.
# Team ID 45475 zaten mevcut, ekleme yapılmadı.
# Team ID 117220 zaten mevcut, ekleme yapılmadı.
# Team ID 7304 zaten mevcut, ekleme yapılmadı.
# Team ID 3349 zaten mevcut, ekleme yapılmadı.
# Team ID 3359 zaten mevcut, ekleme yapılmadı.
# Team ID 47701 zaten mevcut, ekleme yapılmadı.
# Team ID 47700 zaten mevcut, ekleme yapılmadı.
# Team ID 33820 zaten mevcut, ekleme yapılmadı.
# Team ID 6149 zaten mevcut, ekleme yapılmadı.
# Team ID 5235 zaten mevcut, ekleme yapılmadı.
# Team ID 5178 zaten mevcut, ekleme yapılmadı.
# Team ID 1957 zaten mevcut, ekleme yapılmadı.
# Team ID 3280 zaten mevcut, ekleme yapılmadı.
# Team ID 201203 zaten mevcut, ekleme yapılmadı.
# Team ID 252080 zaten mevcut, ekleme yapılmadı.
# Team ID 33595 zaten mevcut, ekleme yapılmadı.
# Team ID 243490 zaten mevcut, ekleme yapılmadı.
# Team ID 39219 zaten mevcut, ekleme yapılmadı.
# Team ID 3150 zaten mevcut, ekleme yapılmadı.
# Team ID 7048 zaten mevcut, ekleme yapılmadı.
# Team ID 6574 zaten mevcut, ekleme yapılmadı.
# Team ID 7047 zaten mevcut, ekleme yapılmadı.
# Team ID 275943 zaten mevcut, ekleme yapılmadı.
# Team ID 3396 zaten mevcut, ekleme yapılmadı.
# Team ID 3404 zaten mevcut, ekleme yapılmadı.
# Team ID 3402 zaten mevcut, ekleme yapılmadı.
# Team ID 3399 zaten mevcut, ekleme yapılmadı.
# Team ID 76775 zaten mevcut, ekleme yapılmadı.
# Team ID 1297 zaten mevcut, ekleme yapılmadı.
# Team ID 1403 zaten mevcut, ekleme yapılmadı.
# Team ID 175002 zaten mevcut, ekleme yapılmadı.
# Team ID 6910 zaten mevcut, ekleme yapılmadı.
# Team ID 116312 zaten mevcut, ekleme yapılmadı.
# Team ID 33819 zaten mevcut, ekleme yapılmadı.
# Team ID 2540 zaten mevcut, ekleme yapılmadı.
# Team ID 2555 zaten mevcut, ekleme yapılmadı.
# Team ID 323848 zaten mevcut, ekleme yapılmadı.
# Team ID 5800 zaten mevcut, ekleme yapılmadı.
# Team ID 43901 zaten mevcut, ekleme yapılmadı.
# Team ID 7864 zaten mevcut, ekleme yapılmadı.
# Team ID 2571 zaten mevcut, ekleme yapılmadı.
# Team ID 41755 zaten mevcut, ekleme yapılmadı.
# Team ID 42611 zaten mevcut, ekleme yapılmadı.
# Team ID 396192 zaten mevcut, ekleme yapılmadı.
# Team ID 213969 zaten mevcut, ekleme yapılmadı.
# Team ID 274973 zaten mevcut, ekleme yapılmadı.
# Team ID 81951 zaten mevcut, ekleme yapılmadı.
# Team ID 404788 zaten mevcut, ekleme yapılmadı.
# Team ID 458766 zaten mevcut, ekleme yapılmadı.
# Team ID 81751 zaten mevcut, ekleme yapılmadı.
# Team ID 25228 zaten mevcut, ekleme yapılmadı.
# Team ID 5761 zaten mevcut, ekleme yapılmadı.
# Team ID 3244 zaten mevcut, ekleme yapılmadı.
# Team ID 894568 zaten mevcut, ekleme yapılmadı.
# Team ID 203021 zaten mevcut, ekleme yapılmadı.
# Team ID 298481 zaten mevcut, ekleme yapılmadı.
# Team ID 375950 zaten mevcut, ekleme yapılmadı.
# Team ID 1896 zaten mevcut, ekleme yapılmadı.
# Team ID 7121 zaten mevcut, ekleme yapılmadı.
# Team ID 86576 zaten mevcut, ekleme yapılmadı.
# Team ID 270969 zaten mevcut, ekleme yapılmadı.
# Team ID 258972 zaten mevcut, ekleme yapılmadı.
# Team ID 2741 zaten mevcut, ekleme yapılmadı.
# Team ID 2782 zaten mevcut, ekleme yapılmadı.
# Team ID 2753 zaten mevcut, ekleme yapılmadı.
# Team ID 43685 zaten mevcut, ekleme yapılmadı.
# Team ID 530559 zaten mevcut, ekleme yapılmadı.
# Team ID 43680 zaten mevcut, ekleme yapılmadı.
# Team ID 228753 zaten mevcut, ekleme yapılmadı.
# Team ID 2803 zaten mevcut, ekleme yapılmadı.
# Team ID 294884 zaten mevcut, ekleme yapılmadı.
# Team ID 43686 zaten mevcut, ekleme yapılmadı.
# Team ID 2720 zaten mevcut, ekleme yapılmadı.
# Team ID 2718 zaten mevcut, ekleme yapılmadı.
# Team ID 205714 zaten mevcut, ekleme yapılmadı.
# Team ID 53857 zaten mevcut, ekleme yapılmadı.
# Team ID 826810 zaten mevcut, ekleme yapılmadı.
# Team ID 826817 zaten mevcut, ekleme yapılmadı.
# Team ID 36142 zaten mevcut, ekleme yapılmadı.
# Team ID 68718 zaten mevcut, ekleme yapılmadı.
# Team ID 5346 zaten mevcut, ekleme yapılmadı.
# Team ID 312564 zaten mevcut, ekleme yapılmadı.
# Team ID 192536 zaten mevcut, ekleme yapılmadı.
# Team ID 3330 zaten mevcut, ekleme yapılmadı.
# Team ID 5206 zaten mevcut, ekleme yapılmadı.
# Team ID 53755 zaten mevcut, ekleme yapılmadı.
# Team ID 38305 zaten mevcut, ekleme yapılmadı.
# Team ID 7704 zaten mevcut, ekleme yapılmadı.
# Team ID 354925 zaten mevcut, ekleme yapılmadı.
# Team ID 1943 zaten mevcut, ekleme yapılmadı.
# Team ID 5265 zaten mevcut, ekleme yapılmadı.
# Team ID 55037 zaten mevcut, ekleme yapılmadı.
# Team ID 226868 zaten mevcut, ekleme yapılmadı.
# Team ID 390513 zaten mevcut, ekleme yapılmadı.
# Team ID 259121 zaten mevcut, ekleme yapılmadı.
# Team ID 6079 zaten mevcut, ekleme yapılmadı.
# Team ID 5212 zaten mevcut, ekleme yapılmadı.
# Team ID 43576 zaten mevcut, ekleme yapılmadı.
# Team ID 677 zaten mevcut, ekleme yapılmadı.
# Team ID 663 zaten mevcut, ekleme yapılmadı.
# Team ID 672 zaten mevcut, ekleme yapılmadı.
# Team ID 903 zaten mevcut, ekleme yapılmadı.
# Team ID 662 zaten mevcut, ekleme yapılmadı.
# Team ID 929 zaten mevcut, ekleme yapılmadı.
# Team ID 1165 zaten mevcut, ekleme yapılmadı.
# Team ID 682 zaten mevcut, ekleme yapılmadı.
# Team ID 62202 zaten mevcut, ekleme yapılmadı.
# Team ID 5064 zaten mevcut, ekleme yapılmadı.
# Team ID 3123 zaten mevcut, ekleme yapılmadı.
# Team ID 37207 zaten mevcut, ekleme yapılmadı.
# Team ID 312033 zaten mevcut, ekleme yapılmadı.
# Team ID 2330 zaten mevcut, ekleme yapılmadı.
# Team ID 75207 zaten mevcut, ekleme yapılmadı.
# Team ID 245709 zaten mevcut, ekleme yapılmadı.
# Team ID 261800 zaten mevcut, ekleme yapılmadı.
# Team ID 2418 zaten mevcut, ekleme yapılmadı.
# Team ID 1781 zaten mevcut, ekleme yapılmadı.
# Team ID 1890 zaten mevcut, ekleme yapılmadı.
# Team ID 379203 zaten mevcut, ekleme yapılmadı.
# Team ID 22238 zaten mevcut, ekleme yapılmadı.
# Team ID 1849 zaten mevcut, ekleme yapılmadı.
# Team ID 1812 zaten mevcut, ekleme yapılmadı.
# Team ID 1829 zaten mevcut, ekleme yapılmadı.
# Team ID 61572 zaten mevcut, ekleme yapılmadı.
# Team ID 7391 zaten mevcut, ekleme yapılmadı.
# Team ID 1886 zaten mevcut, ekleme yapılmadı.
# Team ID 1878 zaten mevcut, ekleme yapılmadı.
# Team ID 59616 zaten mevcut, ekleme yapılmadı.
# Team ID 59622 zaten mevcut, ekleme yapılmadı.
# Team ID 59630 zaten mevcut, ekleme yapılmadı.
# Team ID 35188 zaten mevcut, ekleme yapılmadı.
# Team ID 148874 zaten mevcut, ekleme yapılmadı.
# Team ID 3310 zaten mevcut, ekleme yapılmadı.
# Team ID 5987 zaten mevcut, ekleme yapılmadı.
# Team ID 229644 zaten mevcut, ekleme yapılmadı.
# Team ID 25009 zaten mevcut, ekleme yapılmadı.
# Team ID 22011 zaten mevcut, ekleme yapılmadı.
# Team ID 6881 zaten mevcut, ekleme yapılmadı.
# Team ID 3240 zaten mevcut, ekleme yapılmadı.
# Team ID 6880 zaten mevcut, ekleme yapılmadı.
# Team ID 3229 zaten mevcut, ekleme yapılmadı.
# Team ID 281397 zaten mevcut, ekleme yapılmadı.
# Team ID 44558 zaten mevcut, ekleme yapılmadı.
# Team ID 38013 zaten mevcut, ekleme yapılmadı.
# Team ID 36913 zaten mevcut, ekleme yapılmadı.
# Team ID 134184 zaten mevcut, ekleme yapılmadı.
# Team ID 1653 zaten mevcut, ekleme yapılmadı.
# Team ID 2692 zaten mevcut, ekleme yapılmadı.
# Team ID 42 zaten mevcut, ekleme yapılmadı.
# Team ID 40 zaten mevcut, ekleme yapılmadı.
# Team ID 24264 zaten mevcut, ekleme yapılmadı.
# Team ID 2687 zaten mevcut, ekleme yapılmadı.
# Team ID 1644 zaten mevcut, ekleme yapılmadı.
# Team ID 2829 zaten mevcut, ekleme yapılmadı.
# Team ID 2051 zaten mevcut, ekleme yapılmadı.
# Team ID 1977 zaten mevcut, ekleme yapılmadı.
# Team ID 1961 zaten mevcut, ekleme yapılmadı.
# Team ID 301517 zaten mevcut, ekleme yapılmadı.
# Team ID 120854 zaten mevcut, ekleme yapılmadı.
# Team ID 854567 zaten mevcut, ekleme yapılmadı.
# Team ID 296233 zaten mevcut, ekleme yapılmadı.
# Team ID 78135 zaten mevcut, ekleme yapılmadı.
# Team ID 72070 zaten mevcut, ekleme yapılmadı.
# Team ID 297859 zaten mevcut, ekleme yapılmadı.
# Team ID 206357 zaten mevcut, ekleme yapılmadı.
# Team ID 78113 zaten mevcut, ekleme yapılmadı.
# Team ID 328789 zaten mevcut, ekleme yapılmadı.
# Team ID 392254 zaten mevcut, ekleme yapılmadı.
# Team ID 114685 zaten mevcut, ekleme yapılmadı.
# Team ID 107707 zaten mevcut, ekleme yapılmadı.
# Team ID 390244 zaten mevcut, ekleme yapılmadı.
# Team ID 264769 zaten mevcut, ekleme yapılmadı.
# Team ID 1948 zaten mevcut, ekleme yapılmadı.
# Team ID 1938 zaten mevcut, ekleme yapılmadı.
# Team ID 1931 zaten mevcut, ekleme yapılmadı.
# Team ID 1946 zaten mevcut, ekleme yapılmadı.
# Team ID 22006 zaten mevcut, ekleme yapılmadı.
# Team ID 61 zaten mevcut, ekleme yapılmadı.
# Team ID 34 zaten mevcut, ekleme yapılmadı.
# Team ID 95 zaten mevcut, ekleme yapılmadı.
# Team ID 21 zaten mevcut, ekleme yapılmadı.
# Team ID 12 zaten mevcut, ekleme yapılmadı.
# Team ID 29 zaten mevcut, ekleme yapılmadı.
# Team ID 1 zaten mevcut, ekleme yapılmadı.
# Team ID 2851 zaten mevcut, ekleme yapılmadı.
# Team ID 5067 zaten mevcut, ekleme yapılmadı.
# Team ID 1685 zaten mevcut, ekleme yapılmadı.
# Team ID 22032 zaten mevcut, ekleme yapılmadı.
# Team ID 1968 zaten mevcut, ekleme yapılmadı.
# Team ID 135514 zaten mevcut, ekleme yapılmadı.
# Team ID 2021 zaten mevcut, ekleme yapılmadı.
# Team ID 2973 zaten mevcut, ekleme yapılmadı.
# Team ID 2965 zaten mevcut, ekleme yapılmadı.
# Team ID 2968 zaten mevcut, ekleme yapılmadı.
# Team ID 53067 zaten mevcut, ekleme yapılmadı.
# Team ID 5204 zaten mevcut, ekleme yapılmadı.
# Team ID 23 zaten mevcut, ekleme yapılmadı.
# Team ID 9 zaten mevcut, ekleme yapılmadı.
# Team ID 76 zaten mevcut, ekleme yapılmadı.
# Team ID 134 zaten mevcut, ekleme yapılmadı.
# Team ID 4875 zaten mevcut, ekleme yapılmadı.
# Team ID 86 zaten mevcut, ekleme yapılmadı.
# Team ID 83 zaten mevcut, ekleme yapılmadı.
# Team ID 54 zaten mevcut, ekleme yapılmadı.
# Team ID 133 zaten mevcut, ekleme yapılmadı.
# Team ID 10 zaten mevcut, ekleme yapılmadı.
# Team ID 49 zaten mevcut, ekleme yapılmadı.
# Team ID 64 zaten mevcut, ekleme yapılmadı.
# Team ID 23957 zaten mevcut, ekleme yapılmadı.
# Team ID 97 zaten mevcut, ekleme yapılmadı.
# Team ID 69 zaten mevcut, ekleme yapılmadı.
# Team ID 68 zaten mevcut, ekleme yapılmadı.
# Team ID 84 zaten mevcut, ekleme yapılmadı.
# Team ID 23959 zaten mevcut, ekleme yapılmadı.
# Team ID 20 zaten mevcut, ekleme yapılmadı.
# Team ID 159 zaten mevcut, ekleme yapılmadı.
# Team ID 4 zaten mevcut, ekleme yapılmadı.
# Team ID 37998 zaten mevcut, ekleme yapılmadı.
# Team ID 51 zaten mevcut, ekleme yapılmadı.
# Team ID 26 zaten mevcut, ekleme yapılmadı.
# Team ID 174592 zaten mevcut, ekleme yapılmadı.
# Team ID 5128 zaten mevcut, ekleme yapılmadı.
# Team ID 3138 zaten mevcut, ekleme yapılmadı.
# Team ID 3145 zaten mevcut, ekleme yapılmadı.
# Team ID 282538 zaten mevcut, ekleme yapılmadı.
# Team ID 252254 zaten mevcut, ekleme yapılmadı.
# Team ID 2308 zaten mevcut, ekleme yapılmadı.
# Team ID 2311 zaten mevcut, ekleme yapılmadı.
# Team ID 7668 zaten mevcut, ekleme yapılmadı.
# Team ID 42201 zaten mevcut, ekleme yapılmadı.
# Team ID 186100 zaten mevcut, ekleme yapılmadı.
# Team ID 7653 zaten mevcut, ekleme yapılmadı.
# Team ID 3373 zaten mevcut, ekleme yapılmadı.
# Team ID 34312 zaten mevcut, ekleme yapılmadı.
# Team ID 34316 zaten mevcut, ekleme yapılmadı.
# Team ID 34060 zaten mevcut, ekleme yapılmadı.
# Team ID 189871 zaten mevcut, ekleme yapılmadı.
# Team ID 3135 zaten mevcut, ekleme yapılmadı.
# Team ID 39946 zaten mevcut, ekleme yapılmadı.
# Team ID 3323 zaten mevcut, ekleme yapılmadı.
# Team ID 386185 zaten mevcut, ekleme yapılmadı.
# Team ID 396625 zaten mevcut, ekleme yapılmadı.
# Team ID 33714 zaten mevcut, ekleme yapılmadı.
# Team ID 6968 zaten mevcut, ekleme yapılmadı.
# Team ID 89372 zaten mevcut, ekleme yapılmadı.
# Team ID 89352 zaten mevcut, ekleme yapılmadı.
# Team ID 6110 zaten mevcut, ekleme yapılmadı.
# Team ID 39866 zaten mevcut, ekleme yapılmadı.
# Team ID 89374 zaten mevcut, ekleme yapılmadı.
# Team ID 6119 zaten mevcut, ekleme yapılmadı.
# Team ID 484422 zaten mevcut, ekleme yapılmadı.
# Team ID 89376 zaten mevcut, ekleme yapılmadı.
# Team ID 2220 zaten mevcut, ekleme yapılmadı.
# Team ID 121 zaten mevcut, ekleme yapılmadı.
# Team ID 94 zaten mevcut, ekleme yapılmadı.
# Team ID 166 zaten mevcut, ekleme yapılmadı.
# Team ID 103 zaten mevcut, ekleme yapılmadı.
# Team ID 102 zaten mevcut, ekleme yapılmadı.
# Team ID 73 zaten mevcut, ekleme yapılmadı.
# Team ID 3342 zaten mevcut, ekleme yapılmadı.
# Team ID 138566 zaten mevcut, ekleme yapılmadı.
# Team ID 2256 zaten mevcut, ekleme yapılmadı.
# Team ID 2554 zaten mevcut, ekleme yapılmadı.
# Team ID 2535 zaten mevcut, ekleme yapılmadı.
# Team ID 2566 zaten mevcut, ekleme yapılmadı.
# Team ID 53365 zaten mevcut, ekleme yapılmadı.
# Team ID 6157 zaten mevcut, ekleme yapılmadı.
# Team ID 52767 zaten mevcut, ekleme yapılmadı.
# Team ID 5883 zaten mevcut, ekleme yapılmadı.
# Team ID 2544 zaten mevcut, ekleme yapılmadı.
# Team ID 24267 zaten mevcut, ekleme yapılmadı.
# Team ID 2559 zaten mevcut, ekleme yapılmadı.
# Team ID 5050 zaten mevcut, ekleme yapılmadı.
# Team ID 23949 zaten mevcut, ekleme yapılmadı.
# Team ID 257618 zaten mevcut, ekleme yapılmadı.
# Team ID 275608 zaten mevcut, ekleme yapılmadı.
# Team ID 86578 zaten mevcut, ekleme yapılmadı.
# Team ID 76319 zaten mevcut, ekleme yapılmadı.
# Team ID 316183 zaten mevcut, ekleme yapılmadı.
# Team ID 192763 zaten mevcut, ekleme yapılmadı.
# Team ID 227164 zaten mevcut, ekleme yapılmadı.
# Team ID 55039 zaten mevcut, ekleme yapılmadı.
# Team ID 327830 zaten mevcut, ekleme yapılmadı.
# Team ID 55043 zaten mevcut, ekleme yapılmadı.
# Team ID 41757 zaten mevcut, ekleme yapılmadı.
# Team ID 5181 zaten mevcut, ekleme yapılmadı.
# Team ID 3125 zaten mevcut, ekleme yapılmadı.
# Team ID 386972 zaten mevcut, ekleme yapılmadı.
# Team ID 1807 zaten mevcut, ekleme yapılmadı.
# Team ID 35186 zaten mevcut, ekleme yapılmadı.
# Team ID 4912 zaten mevcut, ekleme yapılmadı.
# Team ID 215559 zaten mevcut, ekleme yapılmadı.
# Team ID 44555 zaten mevcut, ekleme yapılmadı.
# Team ID 48960 zaten mevcut, ekleme yapılmadı.
# Team ID 48972 zaten mevcut, ekleme yapılmadı.
# Team ID 39 zaten mevcut, ekleme yapılmadı.
# Team ID 60 zaten mevcut, ekleme yapılmadı.
# Team ID 32 zaten mevcut, ekleme yapılmadı.
# Team ID 45 zaten mevcut, ekleme yapılmadı.
# Team ID 33 zaten mevcut, ekleme yapılmadı.
# Team ID 35 zaten mevcut, ekleme yapılmadı.
# Team ID 2820 zaten mevcut, ekleme yapılmadı.
# Team ID 24264 zaten mevcut, ekleme yapılmadı.
# Team ID 2833 zaten mevcut, ekleme yapılmadı.
# Team ID 2825 zaten mevcut, ekleme yapılmadı.
# Team ID 2685 zaten mevcut, ekleme yapılmadı.
# Team ID 2695 zaten mevcut, ekleme yapılmadı.
# Team ID 2729 zaten mevcut, ekleme yapılmadı.
# Team ID 2714 zaten mevcut, ekleme yapılmadı.
# Team ID 2696 zaten mevcut, ekleme yapılmadı.
# Team ID 2697 zaten mevcut, ekleme yapılmadı.
# Team ID 2674 zaten mevcut, ekleme yapılmadı.
# Team ID 2672 zaten mevcut, ekleme yapılmadı.
# Team ID 2569 zaten mevcut, ekleme yapılmadı.
# Team ID 2673 zaten mevcut, ekleme yapılmadı.
# Team ID 2538 zaten mevcut, ekleme yapılmadı.
# Team ID 2527 zaten mevcut, ekleme yapılmadı.
# Team ID 1644 zaten mevcut, ekleme yapılmadı.
# Team ID 1715 zaten mevcut, ekleme yapılmadı.
# Team ID 1678 zaten mevcut, ekleme yapılmadı.
# Team ID 3036 zaten mevcut, ekleme yapılmadı.
# Team ID 2998 zaten mevcut, ekleme yapılmadı.
# Team ID 3010 zaten mevcut, ekleme yapılmadı.
# Team ID 483088 zaten mevcut, ekleme yapılmadı.
# Team ID 25777 zaten mevcut, ekleme yapılmadı.
# Team ID 3009 zaten mevcut, ekleme yapılmadı.
# Team ID 3002 zaten mevcut, ekleme yapılmadı.
# Team ID 2961 zaten mevcut, ekleme yapılmadı.
# Team ID 2953 zaten mevcut, ekleme yapılmadı.
# Team ID 2959 zaten mevcut, ekleme yapılmadı.
# Team ID 2957 zaten mevcut, ekleme yapılmadı.
# Team ID 2979 zaten mevcut, ekleme yapılmadı.
# Team ID 2962 zaten mevcut, ekleme yapılmadı.
# Team ID 2960 zaten mevcut, ekleme yapılmadı.
# Team ID 2956 zaten mevcut, ekleme yapılmadı.
# Team ID 1999 zaten mevcut, ekleme yapılmadı.
# Team ID 1967 zaten mevcut, ekleme yapılmadı.
# Team ID 3072 zaten mevcut, ekleme yapılmadı.
# Team ID 3085 zaten mevcut, ekleme yapılmadı.
# Team ID 7040 zaten mevcut, ekleme yapılmadı.
# Team ID 3051 zaten mevcut, ekleme yapılmadı.
# Team ID 2890 zaten mevcut, ekleme yapılmadı.
# Team ID 2929 zaten mevcut, ekleme yapılmadı.
# Team ID 2900 zaten mevcut, ekleme yapılmadı.
# Team ID 169260 zaten mevcut, ekleme yapılmadı.
# Team ID 3255 zaten mevcut, ekleme yapılmadı.
# Team ID 267459 zaten mevcut, ekleme yapılmadı.
# Team ID 5062 zaten mevcut, ekleme yapılmadı.
# Team ID 120154 zaten mevcut, ekleme yapılmadı.
# Team ID 2352 zaten mevcut, ekleme yapılmadı.
# Team ID 2357 zaten mevcut, ekleme yapılmadı.
# Team ID 2354 zaten mevcut, ekleme yapılmadı.
# Team ID 2347 zaten mevcut, ekleme yapılmadı.
# Team ID 2348 zaten mevcut, ekleme yapılmadı.
# Team ID 2359 zaten mevcut, ekleme yapılmadı.
# Team ID 97 zaten mevcut, ekleme yapılmadı.
# Team ID 25935 zaten mevcut, ekleme yapılmadı.
# Team ID 22 zaten mevcut, ekleme yapılmadı.
# Team ID 76 zaten mevcut, ekleme yapılmadı.
# Team ID 134 zaten mevcut, ekleme yapılmadı.
# Team ID 78 zaten mevcut, ekleme yapılmadı.
# Team ID 68 zaten mevcut, ekleme yapılmadı.
# Team ID 19 zaten mevcut, ekleme yapılmadı.
# Team ID 86 zaten mevcut, ekleme yapılmadı.
# Team ID 20 zaten mevcut, ekleme yapılmadı.
# Team ID 18 zaten mevcut, ekleme yapılmadı.
# Team ID 156 zaten mevcut, ekleme yapılmadı.
# Team ID 166 zaten mevcut, ekleme yapılmadı.
# Team ID 79 zaten mevcut, ekleme yapılmadı.
# Team ID 55 zaten mevcut, ekleme yapılmadı.
# Team ID 28 zaten mevcut, ekleme yapılmadı.
# Team ID 103 zaten mevcut, ekleme yapılmadı.
# Team ID 13 zaten mevcut, ekleme yapılmadı.
# Team ID 35038 zaten mevcut, ekleme yapılmadı.
# Team ID 37998 zaten mevcut, ekleme yapılmadı.
# Team ID 7942 zaten mevcut, ekleme yapılmadı.
# Team ID 99 zaten mevcut, ekleme yapılmadı.
# Team ID 133 zaten mevcut, ekleme yapılmadı.
# Team ID 10 zaten mevcut, ekleme yapılmadı.
# Team ID 53 zaten mevcut, ekleme yapılmadı.
# Team ID 229 zaten mevcut, ekleme yapılmadı.
# Team ID 51 zaten mevcut, ekleme yapılmadı.
# Team ID 26 zaten mevcut, ekleme yapılmadı.
# Team ID 128 zaten mevcut, ekleme yapılmadı.
# Team ID 47289 zaten mevcut, ekleme yapılmadı.
# Team ID 62 zaten mevcut, ekleme yapılmadı.
# Team ID 57 zaten mevcut, ekleme yapılmadı.
# Team ID 4 zaten mevcut, ekleme yapılmadı.
# Team ID 6339 zaten mevcut, ekleme yapılmadı.
# Team ID 36467 zaten mevcut, ekleme yapılmadı.
# Team ID 25936 zaten mevcut, ekleme yapılmadı.
# Team ID 159 zaten mevcut, ekleme yapılmadı.
# Team ID 218198 zaten mevcut, ekleme yapılmadı.
# Team ID 189723 zaten mevcut, ekleme yapılmadı.
# Team ID 3211 zaten mevcut, ekleme yapılmadı.
# Team ID 3203 zaten mevcut, ekleme yapılmadı.
# Team ID 7628 zaten mevcut, ekleme yapılmadı.
# Team ID 3215 zaten mevcut, ekleme yapılmadı.
# Team ID 3218 zaten mevcut, ekleme yapılmadı.
# Team ID 1950 zaten mevcut, ekleme yapılmadı.
# Team ID 1932 zaten mevcut, ekleme yapılmadı.
# Team ID 1936 zaten mevcut, ekleme yapılmadı.
# Team ID 1947 zaten mevcut, ekleme yapılmadı.
# Team ID 36246 zaten mevcut, ekleme yapılmadı.
# Team ID 2040 zaten mevcut, ekleme yapılmadı.
# Team ID 25529 zaten mevcut, ekleme yapılmadı.
# Team ID 229348 zaten mevcut, ekleme yapılmadı.
# Team ID 5149 zaten mevcut, ekleme yapılmadı.
# Team ID 43981 zaten mevcut, ekleme yapılmadı.
# Team ID 263360 zaten mevcut, ekleme yapılmadı.
# Team ID 187643 zaten mevcut, ekleme yapılmadı.
# Team ID 243211 zaten mevcut, ekleme yapılmadı.
# Team ID 41618 zaten mevcut, ekleme yapılmadı.
# Team ID 2506 zaten mevcut, ekleme yapılmadı.
# Team ID 2508 zaten mevcut, ekleme yapılmadı.
# Team ID 22010 zaten mevcut, ekleme yapılmadı.
# Team ID 46 zaten mevcut, ekleme yapılmadı.
# Team ID 36 zaten mevcut, ekleme yapılmadı.
# Team ID 25 zaten mevcut, ekleme yapılmadı.
# Team ID 2839 zaten mevcut, ekleme yapılmadı.
# Team ID 24329 zaten mevcut, ekleme yapılmadı.
# Team ID 2852 zaten mevcut, ekleme yapılmadı.
# Team ID 2835 zaten mevcut, ekleme yapılmadı.
# Team ID 2858 zaten mevcut, ekleme yapılmadı.
# Team ID 2822 zaten mevcut, ekleme yapılmadı.
# Team ID 47321 zaten mevcut, ekleme yapılmadı.
# Team ID 2541 zaten mevcut, ekleme yapılmadı.
# Team ID 2567 zaten mevcut, ekleme yapılmadı.
# Team ID 2551 zaten mevcut, ekleme yapılmadı.
# Team ID 2528 zaten mevcut, ekleme yapılmadı.
# Team ID 2675 zaten mevcut, ekleme yapılmadı.
# Team ID 2676 zaten mevcut, ekleme yapılmadı.
# Team ID 2561 zaten mevcut, ekleme yapılmadı.
# Team ID 2712 zaten mevcut, ekleme yapılmadı.
# Team ID 2735 zaten mevcut, ekleme yapılmadı.
# Team ID 2796 zaten mevcut, ekleme yapılmadı.
# Team ID 2716 zaten mevcut, ekleme yapılmadı.
# Team ID 2761 zaten mevcut, ekleme yapılmadı.
# Team ID 2715 zaten mevcut, ekleme yapılmadı.
# Team ID 2793 zaten mevcut, ekleme yapılmadı.
# Team ID 2711 zaten mevcut, ekleme yapılmadı.
# Team ID 1667 zaten mevcut, ekleme yapılmadı.
# Team ID 1654 zaten mevcut, ekleme yapılmadı.
# Team ID 1960 zaten mevcut, ekleme yapılmadı.
# Team ID 2025 zaten mevcut, ekleme yapılmadı.
# Team ID 2001 zaten mevcut, ekleme yapılmadı.
# Team ID 2963 zaten mevcut, ekleme yapılmadı.
# Team ID 2958 zaten mevcut, ekleme yapılmadı.
# Team ID 2972 zaten mevcut, ekleme yapılmadı.
# Team ID 3069 zaten mevcut, ekleme yapılmadı.
# Team ID 3065 zaten mevcut, ekleme yapılmadı.
# Team ID 24759 zaten mevcut, ekleme yapılmadı.
# Team ID 55603 zaten mevcut, ekleme yapılmadı.
# Team ID 5970 zaten mevcut, ekleme yapılmadı.
# Team ID 193723 zaten mevcut, ekleme yapılmadı.
# Team ID 2058 zaten mevcut, ekleme yapılmadı.
# Team ID 2046 zaten mevcut, ekleme yapılmadı.
# Team ID 2051 zaten mevcut, ekleme yapılmadı.
# Team ID 2203 zaten mevcut, ekleme yapılmadı.
# Team ID 5198 zaten mevcut, ekleme yapılmadı.
# Team ID 274894 zaten mevcut, ekleme yapılmadı.
# Team ID 5202 zaten mevcut, ekleme yapılmadı.
# Team ID 3159 zaten mevcut, ekleme yapılmadı.
# Team ID 3167 zaten mevcut, ekleme yapılmadı.
# Team ID 5032 zaten mevcut, ekleme yapılmadı.
# Team ID 3153 zaten mevcut, ekleme yapılmadı.
# Team ID 3155 zaten mevcut, ekleme yapılmadı.
# Team ID 7029 zaten mevcut, ekleme yapılmadı.
# Team ID 7739 zaten mevcut, ekleme yapılmadı.
# Team ID 2218 zaten mevcut, ekleme yapılmadı.
# Team ID 2221 zaten mevcut, ekleme yapılmadı.
# Team ID 6064 zaten mevcut, ekleme yapılmadı.
# Team ID 2217 zaten mevcut, ekleme yapılmadı.
# Team ID 7915 zaten mevcut, ekleme yapılmadı.
# Team ID 3113 zaten mevcut, ekleme yapılmadı.
# Team ID 38729 zaten mevcut, ekleme yapılmadı.
# Team ID 7913 zaten mevcut, ekleme yapılmadı.
# Team ID 3106 zaten mevcut, ekleme yapılmadı.
# Team ID 1289 zaten mevcut, ekleme yapılmadı.
# Team ID 387619 zaten mevcut, ekleme yapılmadı.
# Team ID 323510 zaten mevcut, ekleme yapılmadı.
# Team ID 377757 zaten mevcut, ekleme yapılmadı.
# Team ID 394127 zaten mevcut, ekleme yapılmadı.
# Team ID 134976 zaten mevcut, ekleme yapılmadı.
# Team ID 39723 zaten mevcut, ekleme yapılmadı.
# Team ID 5255 zaten mevcut, ekleme yapılmadı.
# Team ID 42366 zaten mevcut, ekleme yapılmadı.
# Team ID 6910 zaten mevcut, ekleme yapılmadı.
# Team ID 174594 zaten mevcut, ekleme yapılmadı.
# Team ID 174602 zaten mevcut, ekleme yapılmadı.
# Team ID 174600 zaten mevcut, ekleme yapılmadı.
# Team ID 3171 zaten mevcut, ekleme yapılmadı.
# Team ID 3142 zaten mevcut, ekleme yapılmadı.
# Team ID 3135 zaten mevcut, ekleme yapılmadı.
# Team ID 3147 zaten mevcut, ekleme yapılmadı.
# Team ID 21904 zaten mevcut, ekleme yapılmadı.
# Team ID 3143 zaten mevcut, ekleme yapılmadı.
# Team ID 664 zaten mevcut, ekleme yapılmadı.
# Team ID 661 zaten mevcut, ekleme yapılmadı.
# Team ID 659 zaten mevcut, ekleme yapılmadı.
# Team ID 660 zaten mevcut, ekleme yapılmadı.
# Team ID 252245 zaten mevcut, ekleme yapılmadı.
# Team ID 87854 zaten mevcut, ekleme yapılmadı.
# Team ID 2302 zaten mevcut, ekleme yapılmadı.
# Team ID 56021 zaten mevcut, ekleme yapılmadı.
# Team ID 189789 zaten mevcut, ekleme yapılmadı.
# Team ID 7734 zaten mevcut, ekleme yapılmadı.
# Team ID 1762 zaten mevcut, ekleme yapılmadı.
# Team ID 1760 zaten mevcut, ekleme yapılmadı.
# Team ID 1787 zaten mevcut, ekleme yapılmadı.
# Team ID 1767 zaten mevcut, ekleme yapılmadı.
# Team ID 1793 zaten mevcut, ekleme yapılmadı.
# Team ID 2450 zaten mevcut, ekleme yapılmadı.
# Team ID 2442 zaten mevcut, ekleme yapılmadı.
# Team ID 2443 zaten mevcut, ekleme yapılmadı.
# Team ID 2453 zaten mevcut, ekleme yapılmadı.
# Team ID 313716 zaten mevcut, ekleme yapılmadı.
# Team ID 207680 zaten mevcut, ekleme yapılmadı.
# Team ID 174102 zaten mevcut, ekleme yapılmadı.
# Team ID 310970 zaten mevcut, ekleme yapılmadı.
# Team ID 22004 zaten mevcut, ekleme yapılmadı.
# Team ID 285642 zaten mevcut, ekleme yapılmadı.
# Team ID 197070 zaten mevcut, ekleme yapılmadı.
# Team ID 197065 zaten mevcut, ekleme yapılmadı.
# Team ID 148992 zaten mevcut, ekleme yapılmadı.
# Team ID 310531 zaten mevcut, ekleme yapılmadı.
# Team ID 312633 zaten mevcut, ekleme yapılmadı.
# Team ID 312632 zaten mevcut, ekleme yapılmadı.
# Team ID 405295 zaten mevcut, ekleme yapılmadı.
# Team ID 338006 zaten mevcut, ekleme yapılmadı.
# Team ID 2320 zaten mevcut, ekleme yapılmadı.
# Team ID 2321 zaten mevcut, ekleme yapılmadı.
# Team ID 2325 zaten mevcut, ekleme yapılmadı.
# Team ID 285689 zaten mevcut, ekleme yapılmadı.
# Team ID 5131 zaten mevcut, ekleme yapılmadı.
# Team ID 2317 zaten mevcut, ekleme yapılmadı.
# Team ID 34425 zaten mevcut, ekleme yapılmadı.
# Team ID 215083 zaten mevcut, ekleme yapılmadı.
# Team ID 49787 zaten mevcut, ekleme yapılmadı.
# Team ID 151006 zaten mevcut, ekleme yapılmadı.
# Team ID 34714 zaten mevcut, ekleme yapılmadı.
# Team ID 408170 zaten mevcut, ekleme yapılmadı.
# Team ID 7644 zaten mevcut, ekleme yapılmadı.
# Team ID 22020 zaten mevcut, ekleme yapılmadı.
# Team ID 7643 zaten mevcut, ekleme yapılmadı.
# Team ID 7651 zaten mevcut, ekleme yapılmadı.
# Team ID 7652 zaten mevcut, ekleme yapılmadı.
# Team ID 85741 zaten mevcut, ekleme yapılmadı.
# Team ID 338810 zaten mevcut, ekleme yapılmadı.
# Team ID 255501 zaten mevcut, ekleme yapılmadı.
# Team ID 310778 zaten mevcut, ekleme yapılmadı.
# Team ID 234227 zaten mevcut, ekleme yapılmadı.
# Team ID 58687 zaten mevcut, ekleme yapılmadı.
# Team ID 301455 zaten mevcut, ekleme yapılmadı.
# Team ID 266376 zaten mevcut, ekleme yapılmadı.
# Team ID 234204 zaten mevcut, ekleme yapılmadı.
# Team ID 273547 zaten mevcut, ekleme yapılmadı.
# Team ID 266375 zaten mevcut, ekleme yapılmadı.
# Team ID 36704 zaten mevcut, ekleme yapılmadı.
# Team ID 421120 zaten mevcut, ekleme yapılmadı.
# Team ID 368506 zaten mevcut, ekleme yapılmadı.
# Team ID 328498 zaten mevcut, ekleme yapılmadı.
# Team ID 2920 zaten mevcut, ekleme yapılmadı.
# Team ID 295766 zaten mevcut, ekleme yapılmadı.
# Team ID 264963 zaten mevcut, ekleme yapılmadı.
# Team ID 36701 zaten mevcut, ekleme yapılmadı.
# Team ID 306173 zaten mevcut, ekleme yapılmadı.
# Team ID 404735 zaten mevcut, ekleme yapılmadı.
# Team ID 26245 zaten mevcut, ekleme yapılmadı.
# Team ID 389322 zaten mevcut, ekleme yapılmadı.
# Team ID 264911 zaten mevcut, ekleme yapılmadı.
# Team ID 354947 zaten mevcut, ekleme yapılmadı.
# Team ID 389323 zaten mevcut, ekleme yapılmadı.
# Team ID 298858 zaten mevcut, ekleme yapılmadı.
# Team ID 5542 zaten mevcut, ekleme yapılmadı.
# Team ID 322623 zaten mevcut, ekleme yapılmadı.
# Team ID 5556 zaten mevcut, ekleme yapılmadı.
# Team ID 202971 zaten mevcut, ekleme yapılmadı.
# Team ID 38323 zaten mevcut, ekleme yapılmadı.
# Team ID 231057 zaten mevcut, ekleme yapılmadı.
# Team ID 77889 zaten mevcut, ekleme yapılmadı.
# Team ID 114819 zaten mevcut, ekleme yapılmadı.
# Team ID 77897 zaten mevcut, ekleme yapılmadı.
# Team ID 305051 zaten mevcut, ekleme yapılmadı.
# Team ID 25596 zaten mevcut, ekleme yapılmadı.
# Team ID 1923 zaten mevcut, ekleme yapılmadı.
# Team ID 6059 zaten mevcut, ekleme yapılmadı.
# Team ID 1926 zaten mevcut, ekleme yapılmadı.
# Team ID 168476 zaten mevcut, ekleme yapılmadı.
# Team ID 2406 zaten mevcut, ekleme yapılmadı.
# ...
# Match ID 12568786 başarıyla eklendi.
# Match ID 12568788 başarıyla eklendi.
# Match ID 12568785 başarıyla eklendi.
# Match ID 12568792 başarıyla eklendi.
# Match ID 12568791 başarıyla eklendi.
# Match ID 12507361 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-02 16:05:00) while time zone support is active.
#   warnings.warn(
# Match ID 12507362 başarıyla eklendi.
# Match ID 12507358 başarıyla eklendi.
# Match ID 12507369 başarıyla eklendi.
# Match ID 12507363 başarıyla eklendi.
# Match ID 12507356 başarıyla eklendi.
# Match ID 12531758 başarıyla eklendi.
# Match ID 12531755 başarıyla eklendi.
# Match ID 12531753 başarıyla eklendi.
# Match ID 12531754 başarıyla eklendi.
# Match ID 12531750 başarıyla eklendi.
# Match ID 12531757 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-02 16:15:00) while time zone support is active.
#   warnings.warn(
# Match ID 12531749 başarıyla eklendi.
# Match ID 12531752 başarıyla eklendi.
# Match ID 12531756 başarıyla eklendi.
# Match ID 12531518 başarıyla eklendi.
# Match ID 12531513 başarıyla eklendi.
# Match ID 12531511 başarıyla eklendi.
# Match ID 12531517 başarıyla eklendi.
# Match ID 12531514 başarıyla eklendi.
# Match ID 12531524 başarıyla eklendi.
# Match ID 12531512 başarıyla eklendi.
# Match ID 12531519 başarıyla eklendi.
# Match ID 12460008 başarıyla eklendi.
# Match ID 12460003 başarıyla eklendi.
# Match ID 12460005 başarıyla eklendi.
# Match ID 12460000 başarıyla eklendi.
# Match ID 12460006 başarıyla eklendi.
# Match ID 12460004 başarıyla eklendi.
# Match ID 12460002 başarıyla eklendi.
# Match ID 12459999 başarıyla eklendi.
# Match ID 12460007 başarıyla eklendi.
# Match ID 12643031 başarıyla eklendi.
# Match ID 12773790 başarıyla eklendi.
# Match ID 12643029 başarıyla eklendi.
# Match ID 12643033 başarıyla eklendi.
# Match ID 12643027 başarıyla eklendi.
# Match ID 12643070 başarıyla eklendi.
# Match ID 12819297 başarıyla eklendi.
# Match ID 12819296 başarıyla eklendi.
# Match ID 12819299 başarıyla eklendi.
# Match ID 12819294 başarıyla eklendi.
# Match ID 12818305 başarıyla eklendi.
# Match ID 12818299 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-04 14:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12818301 başarıyla eklendi.
# Match ID 12818298 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-04 16:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12818303 başarıyla eklendi.
# Match ID 12640551 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-03 00:45:00) while time zone support is active.
#   warnings.warn(
# Match ID 12640549 başarıyla eklendi.
# Match ID 12640553 başarıyla eklendi.
# Match ID 12523138 başarıyla eklendi.
# Match ID 12640552 başarıyla eklendi.
# Match ID 12523626 başarıyla eklendi.
# Match ID 12651035 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-03 11:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12650969 başarıyla eklendi.
# Match ID 12650966 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-04 11:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12650955 başarıyla eklendi.
# Match ID 12650946 başarıyla eklendi.
# Match ID 12545883 başarıyla eklendi.
# Match ID 12545875 başarıyla eklendi.
# Match ID 12545877 başarıyla eklendi.
# Match ID 12545878 başarıyla eklendi.
# Match ID 12545881 başarıyla eklendi.
# Match ID 12545886 başarıyla eklendi.
# Match ID 12545880 başarıyla eklendi.
# Match ID 12545882 başarıyla eklendi.
# Match ID 12545884 başarıyla eklendi.
# Match ID 12545525 başarıyla eklendi.
# Match ID 12545529 başarıyla eklendi.
# Match ID 12545532 başarıyla eklendi.
# Match ID 12545523 başarıyla eklendi.
# Match ID 12545531 başarıyla eklendi.
# Match ID 12545533 başarıyla eklendi.
# Match ID 12545535 başarıyla eklendi.
# Match ID 12545534 başarıyla eklendi.
# Match ID 12545526 başarıyla eklendi.
# Match ID 12545530 başarıyla eklendi.
# Match ID 12545193 başarıyla eklendi.
# Match ID 12545190 başarıyla eklendi.
# Match ID 12545189 başarıyla eklendi.
# Match ID 12545184 başarıyla eklendi.
# Match ID 12545188 başarıyla eklendi.
# Match ID 12598351 başarıyla eklendi.
# Match ID 12598354 başarıyla eklendi.
# Match ID 12598348 başarıyla eklendi.
# Match ID 12598353 başarıyla eklendi.
# Match ID 12598350 başarıyla eklendi.
# Match ID 12598347 başarıyla eklendi.
# Match ID 12598352 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-04 16:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12598345 başarıyla eklendi.
# Match ID 12007760 başarıyla eklendi.
# Match ID 12007757 başarıyla eklendi.
# Match ID 12007752 başarıyla eklendi.
# Match ID 12007748 başarıyla eklendi.
# Match ID 12007762 başarıyla eklendi.
# Match ID 12007761 başarıyla eklendi.
# Match ID 12007745 başarıyla eklendi.
# Match ID 12007749 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-03 10:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12007737 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-04 08:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12007753 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-03 12:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12177188 başarıyla eklendi.
# Match ID 12177187 başarıyla eklendi.
# Match ID 12177190 başarıyla eklendi.
# Match ID 12177185 başarıyla eklendi.
# Match ID 12085466 başarıyla eklendi.
# Match ID 12085465 başarıyla eklendi.
# Match ID 12085474 başarıyla eklendi.
# Match ID 12085468 başarıyla eklendi.
# Match ID 12085467 başarıyla eklendi.
# Match ID 12444643 başarıyla eklendi.
# Match ID 12444642 başarıyla eklendi.
# Match ID 12651812 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-03 19:15:00) while time zone support is active.
#   warnings.warn(
# Match ID 12444653 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-02 15:15:00) while time zone support is active.
#   warnings.warn(
# Match ID 12991507 başarıyla eklendi.
# Match ID 12991506 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-03 13:45:00) while time zone support is active.
#   warnings.warn(
# Match ID 12991513 başarıyla eklendi.
# Match ID 12653634 başarıyla eklendi.
# Match ID 12653624 başarıyla eklendi.
# Match ID 12653628 başarıyla eklendi.
# Match ID 12653638 başarıyla eklendi.
# Match ID 12590280 başarıyla eklendi.
# Match ID 12590272 başarıyla eklendi.
# Match ID 12531954 başarıyla eklendi.
# Match ID 12531978 başarıyla eklendi.
# Match ID 12738127 başarıyla eklendi.
# Match ID 12531958 başarıyla eklendi.
# Match ID 12969158 başarıyla eklendi.
# Match ID 12969160 başarıyla eklendi.
# Match ID 12969167 başarıyla eklendi.
# Match ID 12969159 başarıyla eklendi.
# Match ID 12969162 başarıyla eklendi.
# Match ID 12969156 başarıyla eklendi.
# Match ID 12969169 başarıyla eklendi.
# Match ID 12621712 başarıyla eklendi.
# Match ID 12621713 başarıyla eklendi.
# Match ID 12621714 başarıyla eklendi.
# Match ID 12621708 başarıyla eklendi.
# Match ID 12621711 başarıyla eklendi.
# Match ID 12621710 başarıyla eklendi.
# Match ID 12472180 başarıyla eklendi.
# Match ID 12472182 başarıyla eklendi.
# Match ID 12472195 başarıyla eklendi.
# Match ID 12472169 başarıyla eklendi.
# Match ID 11918320 başarıyla eklendi.
# Match ID 11918313 başarıyla eklendi.
# Match ID 11918314 başarıyla eklendi.
# Match ID 11918316 başarıyla eklendi.
# Match ID 11918317 başarıyla eklendi.
# Match ID 11918318 başarıyla eklendi.
# Match ID 11918319 başarıyla eklendi.
# Match ID 11918321 başarıyla eklendi.
# Match ID 13077984 başarıyla eklendi.
# Match ID 11918577 başarıyla eklendi.
# Match ID 11965936 başarıyla eklendi.
# Match ID 11918560 başarıyla eklendi.
# Match ID 11918559 başarıyla eklendi.
# Match ID 11918568 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-03 11:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 13023295 başarıyla eklendi.
# Match ID 12448854 başarıyla eklendi.
# Match ID 12448852 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-02 21:35:00) while time zone support is active.
#   warnings.warn(
# Match ID 12448850 başarıyla eklendi.
# Match ID 12448853 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-03 16:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12448844 başarıyla eklendi.
# Match ID 12448857 başarıyla eklendi.
# Match ID 12518412 başarıyla eklendi.
# Match ID 12518411 başarıyla eklendi.
# Match ID 12518414 başarıyla eklendi.
# Match ID 12518415 başarıyla eklendi.
# Match ID 12518410 başarıyla eklendi.
# Match ID 12518407 başarıyla eklendi.
# Match ID 12592419 başarıyla eklendi.
# Match ID 12592414 başarıyla eklendi.
# Match ID 12592415 başarıyla eklendi.
# Match ID 12592344 başarıyla eklendi.
# Match ID 12592347 başarıyla eklendi.
# Match ID 12592330 başarıyla eklendi.
# Match ID 12618948 başarıyla eklendi.
# Match ID 12493963 başarıyla eklendi.
# Match ID 12493970 başarıyla eklendi.
# Match ID 12493967 başarıyla eklendi.
# Match ID 12493960 başarıyla eklendi.
# Match ID 12493962 başarıyla eklendi.
# Match ID 12493968 başarıyla eklendi.
# Match ID 12493965 başarıyla eklendi.
# Match ID 12476915 başarıyla eklendi.
# Match ID 12476912 başarıyla eklendi.
# Match ID 12476914 başarıyla eklendi.
# Match ID 12476913 başarıyla eklendi.
# Match ID 12476749 başarıyla eklendi.
# Match ID 12476754 başarıyla eklendi.
# Match ID 12476748 başarıyla eklendi.
# Match ID 12476739 başarıyla eklendi.
# Match ID 12476741 başarıyla eklendi.
# Match ID 12476591 başarıyla eklendi.
# Match ID 12476590 başarıyla eklendi.
# Match ID 12476589 başarıyla eklendi.
# Match ID 12476588 başarıyla eklendi.
# Match ID 12476587 başarıyla eklendi.
# Match ID 12885754 başarıyla eklendi.
# Match ID 12885753 başarıyla eklendi.
# Match ID 12246976 başarıyla eklendi.
# Match ID 12484248 başarıyla eklendi.
# Match ID 12484253 başarıyla eklendi.
# Match ID 12484259 başarıyla eklendi.
# Match ID 12484251 başarıyla eklendi.
# Match ID 12484245 başarıyla eklendi.
# Match ID 12196921 başarıyla eklendi.
# Match ID 12196917 başarıyla eklendi.
# Match ID 12196920 başarıyla eklendi.
# Match ID 12196918 başarıyla eklendi.
# Match ID 12196922 başarıyla eklendi.
# Match ID 12196919 başarıyla eklendi.
# Match ID 12196923 başarıyla eklendi.
# Match ID 11988881 başarıyla eklendi.
# Match ID 11988879 başarıyla eklendi.
# Match ID 11988883 başarıyla eklendi.
# Match ID 11988882 başarıyla eklendi.
# Match ID 11988878 başarıyla eklendi.
# Match ID 11988877 başarıyla eklendi.
# Match ID 11988876 başarıyla eklendi.
# Match ID 11988606 başarıyla eklendi.
# Match ID 11988605 başarıyla eklendi.
# Match ID 11988610 başarıyla eklendi.
# Match ID 11988630 başarıyla eklendi.
# Match ID 11988619 başarıyla eklendi.
# Match ID 11988618 başarıyla eklendi.
# Match ID 11988632 başarıyla eklendi.
# Match ID 11988628 başarıyla eklendi.
# Match ID 11922111 başarıyla eklendi.
# Match ID 11922115 başarıyla eklendi.
# Match ID 11922112 başarıyla eklendi.
# Match ID 11922113 başarıyla eklendi.
# Match ID 11922116 başarıyla eklendi.
# Match ID 11922110 başarıyla eklendi.
# Match ID 13029230 başarıyla eklendi.
# Match ID 13024124 başarıyla eklendi.
# Match ID 13024125 başarıyla eklendi.
# Match ID 13029229 başarıyla eklendi.
# Match ID 13024114 başarıyla eklendi.
# Match ID 13024115 başarıyla eklendi.
# Match ID 13024122 başarıyla eklendi.
# Match ID 13024117 başarıyla eklendi.
# Match ID 12632705 başarıyla eklendi.
# Match ID 12484424 başarıyla eklendi.
# Match ID 12484427 başarıyla eklendi.
# Match ID 12484429 başarıyla eklendi.
# Match ID 12481982 başarıyla eklendi.
# Match ID 12484425 başarıyla eklendi.
# Match ID 12484430 başarıyla eklendi.
# Match ID 13018803 başarıyla eklendi.
# Match ID 13018804 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-03 03:15:00) while time zone support is active.
#   warnings.warn(
# Match ID 13018806 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-03 15:45:00) while time zone support is active.
#   warnings.warn(
# Match ID 13018845 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-03 22:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 13018846 başarıyla eklendi.
# Match ID 13018848 başarıyla eklendi.
# Match ID 13014312 başarıyla eklendi.
# Match ID 13014301 başarıyla eklendi.
# Match ID 13014304 başarıyla eklendi.
# Match ID 13014310 başarıyla eklendi.
# Match ID 12694122 başarıyla eklendi.
# Match ID 12694125 başarıyla eklendi.
# Match ID 12694133 başarıyla eklendi.
# Match ID 12454759 başarıyla eklendi.
# Match ID 12454760 başarıyla eklendi.
# Match ID 12454761 başarıyla eklendi.
# Match ID 12454762 başarıyla eklendi.
# Match ID 12454763 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-11-02 20:15:00) while time zone support is active.
#   warnings.warn(
# Match ID 12454758 başarıyla eklendi.
# Match ID 13062641 başarıyla eklendi.
# Match ID 13062642 başarıyla eklendi.
# İşlemler bitti
